# %%
from datasets import load_dataset

dataset = load_dataset("osunlp/Multimodal-Mind2Web")
# Out:
# Resolving data files:   0%|          | 0/27 [00:00<?, ?it/s]

# %%
import json
t = json.load(open("test_website_outputs_top50.json"))
test_website_ids = {}

for tt in t:
    test_website_ids[tt[0]] = tt

# %%
from IPython.display import clear_output

data = []

curr_task_id = ""
curr_action_index = 0
for i, item in enumerate(dataset["test_website"]):
    
    task = item["confirmed_task"]
    operation = item["operation"]
    raw_html = item["raw_html"]
    cleaned_html = item["cleaned_html"]
    screenshot = item["screenshot"]
    
    task_id = item["annotation_id"]
    action_id = item["action_uid"]
    
    combined_id = task_id + "_" + action_id
    if len(test_website_ids[combined_id]) < 3:
        curr_action_index += 1
        continue
    pos_candidates = test_website_ids[combined_id][2]["pos_candidates"]
    neg_candidates = test_website_ids[combined_id][2]["neg_candidates"]
    all_candidates = pos_candidates + neg_candidates
    ranked_candidates = sorted(all_candidates, key= lambda x: x["rank"])[:100]
    
    if task_id != curr_task_id:
        curr_task_id = task_id
        # data[task_id] = []
        curr_action_index = 0
    action_sequence = item["action_reprs"]
    actions_so_far = action_sequence[:curr_action_index]
    curr_action_index += 1
    
    data.append({
        "action_id": action_id,
        "task_id": task_id,
        "pos_candidates": pos_candidates,
        "ranked_candidates": ranked_candidates,
        "actions_so_far": actions_so_far,
        "task": task,
        # "cleaned_html": cleaned_html,
        # "raw_html": raw_html,
        "screenshot": screenshot,
        "operation": operation
    })
    
    clear_output()
    print(i)
    # if i == 100:
    #     break
# Out:
# 1018

# %%
prompt_1_1 = """You are DeltAct, a web agent whose job is to imitate humans doing web navigation for a task step by step. 
At each stage, you can see the webpage like humans by a screenshot and know the previous actions before the current step decided by yourself through recorded history. 
You need to decide on the first following action to take. You can click an element with the mouse, select an option, or type text with the keyboard. 
(For your understanding, they are like the click(), select_option() and type() functions in playwright respectively)
One next step means one operation within the three.

There is some overarching task you are trying to accomplish, and you are currently at some step of the task (could be any step).
You will be given the webpage screenshot, the simplified DOM containing some elements of interest, the original task and the sequence of actions taken so far.

You need to consider all these and first think through the problem. Think about each of the following areas:

(Current Webpage Analysis)
Firstly, think about what the current webpage is.

(Previous Action Analysis)
Secondly, combined with the screenshot, analyze each step of the previous action history and their intention one by one. Particularly, pay more attention to the last step, which may be more related to what you should do now as the next step. Specifically, if the last action involved a TYPE, always evaluate whether it necessitates a confirmation step, because typically a single TYPE action does not make effect. (often, simply pressing 'Enter', assuming the default element involved in the last action, unless other clear elements are present for operation).

(Screenshot Details Analysis)
Closely examine the screenshot to check the status of every part of the webpage to understand what you can operate with and what has been set or completed. You should closely examine the screenshot details to see what steps have been completed by previous actions even though you are given the textual previous actions. Because the textual history may not clearly and sufficiently record some effects of previous actions, you should closely evaluate the status of every part of the webpage to understand what you have done.

(Next Action Based on Webpage and Analysis)
Then, based on your analysis, in conjunction with human web browsing habits and the logic of web design, decide on the following action. And clearly outline which element in the webpage users will operate with as the first next target element, its detailed location, and the corresponding operation. Only think through this, don't issue an action right now.

Once you have thought through each of these, propose 3 actions that seem most likely to be the correct one. For each action, provide the following:

(Proposed Action Element)
The index of the element that the action is to be performed on

(Proposed Action Op)
The operation to be performed on the element. Must be one of CLICK, TYPE, SELECT

(Proposed Action Value)
Optional value for the operation, e.g., text to type, option to select

Then, select one of these 3 to be the Prefinal Action. This is the Action you think is the most likely to be the correct one. Provide the above 3 fields for the Prefinal Action.

Then, perform a Validity Check on the Prefinal Action:

(Validity Check)
Check whether the Action is valid and correct by thinking through it.

Then, provide the Final Action in the same format:

(Final Action Element)
The index of the element that the action is to be performed on

(Final Action Op)
The operation to be performed on the element. Must be one of CLICK, TYPE, SELECT

(Final Action Value)
Optional value for the operation, e.g., text to type, option to select

Here are the webpage screenshot, the simplified DOM containing some elements of interest (alongside their bounding box coordinates in [left, top, right, bottom] format), the original overarching task and the sequence of actions taken so far (this sequence is described in a somewhat cryptic format):

**Simplified DOM**
{simplified_dom}

**Task**
{task}

**Actions Taken So Far**
{actions_so_far}
"""

# prompt_1_2 = """
# """

# prompt_2_1 = """You are DeltAct, a web agent whose job is to imitate humans doing web navigation for a task step by step. 
# At each stage, you can see the webpage like humans by a screenshot and know the previous actions before the current step decided by yourself through recorded history. 
# You need to decide on the first following action to take. You can click an element with the mouse, select an option, or type text with the keyboard. 
# (For your understanding, they are like the click(), select_option() and type() functions in playwright respectively)
# One next step means one operation within the three.

# There is some overarching task you are trying to accomplish, and you are currently at some step of the task (could be any step).
# You will be given the webpage screenshot, the simplified DOM containing some elements of interest (alongside their bounding box coordinates in [left, top, right, bottom] format), the original task and the sequence of actions taken so far.

# Here are some thoughts and analysis of the current step:

# (Current Webpage Analysis)
# {current_webpage_analysis}

# (Previous Action Analysis)
# {previous_action_analysis}

# (Screenshot Details Analysis)
# {screenshot_details_analysis}

# (Next Action Based on Webpage and Analysis)
# {next_action_analysis}
# """

# prompt_2_2 = """Here are the webpage screenshot, the simplified DOM containing some elements of interest, the original overarching task and the sequence of actions taken so far (this sequence is described in a somewhat cryptic format):

# **Simplified DOM**
# {simplified_dom}

# **Task**
# {task}

# **Actions Taken So Far**
# {actions_so_far}
# """

# %%
import instructor
from pydantic import BaseModel
from openai import OpenAI
from anthropic import Anthropic
import base64
from io import BytesIO
import supervision as sv
from image_utils import batch_elements_by_locality_16_16_17, convert_elements2detections 
import numpy as np
from PIL import Image

target_w = 700
target_h = 1100

class Response1(BaseModel):
    current_webpage_analysis: str
    previous_action_analysis: str
    screenshot_details_analysis: str
    next_action_analysis: str
    proposed_action_1_element: int
    proposed_action_1_op: str
    proposed_action_1_value: str
    proposed_action_2_element: int
    proposed_action_2_op: str
    proposed_action_2_value: str
    proposed_action_3_element: int
    proposed_action_3_op: str
    proposed_action_3_value: str
    prefinal_action_element: int
    prefinal_action_op: str
    prefinal_action_value: str
    validity_check: str
    final_action_element: int
    final_action_op: str
    final_action_value: str

element_acc = []
action_f1 = []
step_acc = []

def process_and_encode_image(screenshot, ranked_candidates):
    
    bounding_box_annotator = sv.BoundingBoxAnnotator(
        thickness=2
    )
    candidate_label_annotator = sv.LabelAnnotator(
        color_lookup=sv.ColorLookup.INDEX,
        text_position=sv.Position.BOTTOM_LEFT,
        text_scale=0.5,
        text_color=sv.Color.white(),
        color=sv.Color.black(),
        text_thickness=1
    )
    
    candidate_detections = convert_elements2detections(ranked_candidates)
    candidate_labels = [str(i) for i in range(len(candidate_detections))]
    
    annotated_image = bounding_box_annotator.annotate(scene=np.array(screenshot), detections=candidate_detections)
    annotated_image = candidate_label_annotator.annotate(scene=annotated_image, detections=candidate_detections, labels=candidate_labels)
    screenshot = Image.fromarray(annotated_image)
    screenshot = screenshot.resize((target_w, target_h))
    screenshot.save("temp.jpg")
    with open("temp.jpg", "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

def get_simplified_dom(ranked_candidates, scale_x, scale_y):
    simplified_dom = []
    
    for candidate in ranked_candidates:
        attributes = json.loads(candidate["attributes"])
        if "backend_node_id" in attributes:
            del attributes["backend_node_id"]
        if "class" in attributes:
            del attributes["class"]
        if "data_pw_testid_buckeye_candidate" in attributes:
            del attributes["data_pw_testid_buckeye_candidate"]
        if "is_original_target" in attributes:
            del attributes["is_original_target"]
        if "is_top_level_target" in attributes:
            del attributes["is_top_level_target"]
        
        bounding_box_rect = attributes["bounding_box_rect"]
        x1, y1, w, h = bounding_box_rect.split(",")
        l = str(int(float(x1)/scale_x))
        t = str(int(float(y1)/scale_y))
        r = str(int(float(x1)/scale_x) + int(float(w)/scale_x))
        b = str(int(float(y1)/scale_y) + int(float(h)/scale_y))
        attributes["bounding_box_rect"] = ",".join([l, t, r, b])
        
        attribute_str = ""
        for k in attributes.keys():
            attribute_str += " " + k + "=" + attributes[k]
        
        current_elem = str(candidate["rank"]) + ". " + "<" + candidate["tag"] + attribute_str +">"
        simplified_dom.append(current_elem)
        
    simplified_dom = "\n".join(simplified_dom)
    return simplified_dom

def deltact_gpt4v(simplified_dom, task, actions_so_far, screenshot):
    client = instructor.from_openai(OpenAI(api_key=""))
    base64_image = process_and_encode_image(screenshot, ranked_candidates)
    response = client.chat.completions.create(
        model="gpt-4-turbo-2024-04-09",
        response_model=Response1,
        messages=[
            # {"role": "user", "content": prompt_1_1},
            {"role": "user", "content": [
                    {"type": "text", "text": prompt_1_1.format(simplified_dom=simplified_dom, task=task, actions_so_far = actions_so_far)},
                    {
                      "type": "image_url",
                      "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}",
                        "detail": "high"
                      },
                    },
                ],
            },
        ],
    )
    return response

def deltact_claude_haiku(simplified_dom, task, actions_so_far, screenshot):
    client = instructor.from_anthropic(Anthropic(api_key=""))
    base64_image = process_and_encode_image(screenshot, ranked_candidates)
    response = client.messages.create(
        model="claude-3-haiku-20240307",
        max_tokens=1024,
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": prompt_1_1.format(simplified_dom=simplified_dom, task=task, actions_so_far = actions_so_far)
                    },
                    {
                        "type": "image",
                        "source": {
                            "type": "base64",
                            "media_type": "image/jpeg",
                            "data": base64_image,
                        },
                    }
                ],
            }
        ],
        response_model = Response1
    )
    return response

def deltact_claude_sonnet(simplified_dom, task, actions_so_far, screenshot):
    client = instructor.from_anthropic(Anthropic(api_key=""))
    base64_image = process_and_encode_image(screenshot, ranked_candidates)
    response = client.messages.create(
        model="claude-3-sonnet-20240229",
        max_tokens=1024,
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": prompt_1_1.format(simplified_dom=simplified_dom, task=task, actions_so_far = actions_so_far)
                    },
                    {
                        "type": "image",
                        "source": {
                            "type": "base64",
                            "media_type": "image/jpeg",
                            "data": base64_image,
                        },
                    }
                ],
            }
        ],
        response_model = Response1
    )
    return response

# %%
# temp = data[0]

# process_and_encode_image(temp["screenshot"], ranked_candidates)

# %%
import numpy as np

def evaluate(results):
    
    element_acc = []
    action_acc = []
    step_acc = []
    
    for result in results:
        pos_candidates = result["expected"]["pos_candidates"]
        op = json.loads(result["expected"]["operation"])["op"]
        response_element = result["response"]["final_action_element"]
        response_op = result["response"]["final_action_op"]

        pos_ranks = [candidate["rank"] for candidate in pos_candidates]
        if response_element in pos_ranks:
            element_acc.append(1)
        else:
            element_acc.append(0)
        if response_op == op:
            action_acc.append(1)
        else:
            action_acc.append(0)
        if element_acc[-1] == 1 and action_acc[-1] == 1:
            step_acc.append(1)
        else:
            step_acc.append(0)
    
    return {
        "element_acc": np.mean(element_acc),
        "action_f1": np.mean(action_acc),
        "step_sr": np.mean(step_acc)
    }

# %%
results = []

import time
from IPython.display import clear_output

for item in data:
    
    start_time = time.time()
    
    task = item["task"]
    operation = item["operation"]
    screenshot = item["screenshot"]
    actions_so_far = "\n".join(item["actions_so_far"])
    ranked_candidates = item["ranked_candidates"][:50]
    
    scale_x = screenshot.size[0] / target_w
    scale_y = screenshot.size[1] / target_h
    
    simplified_dom = get_simplified_dom(ranked_candidates, scale_x, scale_y)
    print(simplified_dom)
    break
    try:
        response = deltact_claude_haiku(simplified_dom, task, actions_so_far, screenshot)
        response = response.dict()

        results.append({
            "expected": {
                "pos_candidates": item["pos_candidates"],
                "operation": operation
            },
            "response": response
        })

        while 1:
            curr_time = time.time()
            if curr_time - start_time >= 20:
                break
    except:
        continue
    
    clear_output()
    print(len(results))
    print(evaluate(results))
# Out:
# 0. <label bounding_box_rect=33,569,72,578 is_clickable=true>
# 1. <label bounding_box_rect=33,731,77,740 is_clickable=true>
# 2. <label bounding_box_rect=33,539,72,548 is_clickable=true>
# 3. <button bounding_box_rect=608,276,657,286 type=button>
# 4. <input bounding_box_rect=485,278,601,284 placeholder=Input artist name type=text value= input_value= is_clickable=true>
# 5. <input bounding_box_rect=415,278,459,284 placeholder=Please select type=text value=Artist Name input_value=Artist Name is_clickable=true>
# 6. <input bounding_box_rect=201,148,349,154 placeholder=Please select type=text value=United States input_value=United States is_clickable=true>
# 7. <a bounding_box_rect=156,884,274,891 is_clickable=true>
# 8. <a bounding_box_rect=300,103,335,112 is_clickable=true>
# 9. <span bounding_box_rect=33,426,142,440>
# 10. <label bounding_box_rect=33,205,65,214 is_clickable=true>
# 11. <label bounding_box_rect=33,618,87,627 is_clickable=true>
# 12. <label bounding_box_rect=33,169,90,179 is_clickable=true>
# 13. <label bounding_box_rect=33,195,52,204 is_clickable=true>
# 14. <label bounding_box_rect=33,249,52,258 is_clickable=true>
# 15. <label bounding_box_rect=33,441,52,450 is_clickable=true>
# 16. <label bounding_box_rect=33,672,52,681 is_clickable=true>
# 17. <label bounding_box_rect=33,509,104,518 is_clickable=true>
# 18. <span bounding_box_rect=570,478,613,486>
# 19. <a bounding_box_rect=290,875,408,882 is_clickable=true>
# 20. <img bounding_box_rect=13,8,138,13 alt=Tiktok for business title=Tiktok for business>
# 21. <a bounding_box_rect=382,26,431,33 is_clickable=true>
# 22. <a bounding_box_rect=156,942,274,949 is_clickable=true>
# 23. <a bounding_box_rect=290,865,408,872 is_clickable=true>
# 24. <label bounding_box_rect=33,628,90,637 is_clickable=true>
# 25. <a bounding_box_rect=246,40,352,47 is_clickable=true>
# 26. <label bounding_box_rect=33,357,60,366 is_clickable=true>
# 27. <a bounding_box_rect=156,894,274,901 is_clickable=true>
# 28. <div bounding_box_rect=361,435,425,441>
# 29. <div bounding_box_rect=361,663,425,669>
# 30. <div bounding_box_rect=361,618,425,624>
# 31. <div bounding_box_rect=361,389,425,395>
# 32. <div bounding_box_rect=361,412,425,418>
# 33. <div bounding_box_rect=361,458,425,464>
# 34. <div bounding_box_rect=361,595,425,601>
# 35. <a bounding_box_rect=290,884,408,891 is_clickable=true>
# 36. <div bounding_box_rect=194,267,315,288>
# 37. <div bounding_box_rect=173,297,348,312>
# 38. <a bounding_box_rect=13,8,138,13 is_clickable=true>
# 39. <label bounding_box_rect=478,276,608,286 is_clickable=true>
# 40. <a bounding_box_rect=194,163,505,184 is_clickable=true>
# 41. <a bounding_box_rect=460,7,505,13 is_clickable=true>
# 42. <a bounding_box_rect=246,54,352,61 is_clickable=true>
# 43. <span bounding_box_rect=510,7,523,10>
# 44. <a bounding_box_rect=246,97,352,104 is_clickable=true>
# 45. <span bounding_box_rect=33,144,142,158>
# 46. <span bounding_box_rect=33,657,142,671>
# 47. <label bounding_box_rect=33,836,71,846 is_clickable=true>
# 48. <label bounding_box_rect=407,276,478,286 is_clickable=true>
# 49. <img bounding_box_rect=415,27,424,32 alt=navArrow title=navArrow>

# %%
evaluate(results)

# %%
# Out:
# {'action_id': '79c4a963-4aa9-49c1-9257-6b0d5069c551',
#  'task_id': '013781df-4391-4533-bcb1-15f6819064f6',
#  'pos_candidates': [{'attributes': '{"backend_node_id": "110", "bounding_box_rect": "356,461,320,34", "class": "byted-input-inner__wrapper byted-input-inner__wrapper-border byted-input-inner__wrapper-size-md byted-input-inner__wrapper-add-suffix", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '110',
#    'is_original_target': True,
#    'is_top_level_target': True,
#    'rank': 70,
#    'score': 0.0012499975273385644,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "828", "bounding_box_rect": "369,467,272,22", "placeholder": "Please select", "type": "text", "class": "byted-input byted-input-size-md", "value": "United States", "input_value": "United States", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '828',
#    'is_original_target': False,
#    'is_top_level_target': False,
#    'rank': 6,
#    'score': 0.9167003035545349,
#    'tag': 'input'}],
#  'ranked_candidates': [{'attributes': '{"backend_node_id": "635", "bounding_box_rect": "62,1792,72,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '635',
#    'rank': 0,
#    'score': 0.9708621501922607,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "739", "bounding_box_rect": "62,2303,81,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '739',
#    'rank': 1,
#    'score': 0.9669984579086304,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "617", "bounding_box_rect": "62,1699,72,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '617',
#    'rank': 2,
#    'score': 0.9440830945968628,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "892", "bounding_box_rect": "1113,872,91,34", "type": "button", "class": "byted-btn byted-btn-size-md byted-btn-type-primary byted-btn-shape-angle byted-can-input-grouped searchBtn--yoHyL", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '892',
#    'rank': 3,
#    'score': 0.9323874711990356,
#    'tag': 'button'},
#   {'attributes': '{"backend_node_id": "891", "bounding_box_rect": "888,878,213,22", "placeholder": "Input artist name", "type": "text", "class": "byted-input byted-input-size-md", "value": "", "input_value": "", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '891',
#    'rank': 4,
#    'score': 0.9278078079223633,
#    'tag': 'input'},
#   {'attributes': '{"backend_node_id": "882", "bounding_box_rect": "759,878,82,22", "placeholder": "Please select", "type": "text", "class": "byted-input byted-input-size-md", "value": "Artist Name", "input_value": "Artist Name", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '882',
#    'rank': 5,
#    'score': 0.9245426058769226,
#    'tag': 'input'},
#   {'attributes': '{"backend_node_id": "828", "bounding_box_rect": "369,467,272,22", "placeholder": "Please select", "type": "text", "class": "byted-input byted-input-size-md", "value": "United States", "input_value": "United States", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '828',
#    'is_original_target': False,
#    'is_top_level_target': False,
#    'rank': 6,
#    'score': 0.9167003035545349,
#    'tag': 'input'},
#   {'attributes': '{"backend_node_id": "1613", "bounding_box_rect": "286,2786.5625,216,22.390625", "class": "link--L6Xda", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1613',
#    'rank': 7,
#    'score': 0.8825053572654724,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "327", "bounding_box_rect": "549.5,327,65,29", "class": "navItem--d5sIk", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '327',
#    'rank': 8,
#    'score': 0.8797560930252075,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "546", "bounding_box_rect": "62,1343,200,46", "class": "byted-menu-line-title", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '546',
#    'rank': 9,
#    'score': 0.8759732246398926,
#    'tag': 'span'},
#   {'attributes': '{"backend_node_id": "403", "bounding_box_rect": "62,646,59,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '403',
#    'rank': 10,
#    'score': 0.8618301153182983,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "665", "bounding_box_rect": "62,1947,99,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '665',
#    'rank': 11,
#    'score': 0.8518990278244019,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "369", "bounding_box_rect": "62,535,106,34", "class": "byted-radio byted-radio-size-md radio--tZPUV", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '369',
#    'rank': 12,
#    'score': 0.7541305422782898,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "396", "bounding_box_rect": "62,615,35,31", "class": "byted-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '396',
#    'rank': 13,
#    'score': 0.6745551228523254,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "434", "bounding_box_rect": "62,785,35,31", "class": "byted-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '434',
#    'rank': 14,
#    'score': 0.6745551228523254,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "556", "bounding_box_rect": "62,1389,35,31", "class": "byted-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '556',
#    'rank': 15,
#    'score': 0.6745551228523254,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "702", "bounding_box_rect": "62,2117,35,31", "class": "byted-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '702',
#    'rank': 16,
#    'score': 0.6745551228523254,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "599", "bounding_box_rect": "62,1606,130,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '599',
#    'rank': 17,
#    'score': 0.5182971954345703,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "1162", "bounding_box_rect": "1043.703125,1507.5,79,26", "class": "byted-tag byted-tag-size-md byted-tag-default-light commonTag--zIh8J", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1162',
#    'rank': 18,
#    'score': 0.3928443193435669,
#    'tag': 'span'},
#   {'attributes': '{"backend_node_id": "1634", "bounding_box_rect": "532,2756.171875,216,22.390625", "class": "link--L6Xda", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1634',
#    'rank': 19,
#    'score': 0.16344451904296875,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "106", "bounding_box_rect": "24,26,230,18", "class": "logo-img--5nL7B logo-img--u+YIO", "alt": "Tiktok for business", "title": "Tiktok for business", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '106',
#    'rank': 20,
#    'score': 0.145601287484169,
#    'tag': 'img'},
#   {'attributes': '{"backend_node_id": "288", "bounding_box_rect": "700,83,91,25", "class": "dropdownItem--VF-DB active--2JTRS", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '288',
#    'rank': 21,
#    'score': 0.13989166915416718,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "1625", "bounding_box_rect": "286,2968.90625,216,22.390625", "class": "link--L6Xda", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1625',
#    'rank': 22,
#    'score': 0.09978979825973511,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "1632", "bounding_box_rect": "532,2725.78125,216,22.390625", "class": "link--L6Xda", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1632',
#    'rank': 23,
#    'score': 0.08924055844545364,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "671", "bounding_box_rect": "62,1978,106,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '671',
#    'rank': 24,
#    'score': 0.08601269870996475,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "237", "bounding_box_rect": "450,128,195,25", "class": "dropdownItem--VF-DB", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '237',
#    'rank': 25,
#    'score': 0.06201000139117241,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "501", "bounding_box_rect": "62,1126,50,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '501',
#    'rank': 26,
#    'score': 0.04144114628434181,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "1615", "bounding_box_rect": "286,2816.953125,216,22.390625", "class": "link--L6Xda", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1615',
#    'rank': 27,
#    'score': 0.027380989864468575,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "1077", "bounding_box_rect": "660.5,1370.5,117.046875,19", "class": "artist--Q4Rf9", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1077',
#    'rank': 28,
#    'score': 0.020711449906229973,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "1387", "bounding_box_rect": "660.5,2090.5,117.046875,19", "class": "artist--Q4Rf9", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1387',
#    'rank': 29,
#    'score': 0.019252803176641464,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "1322", "bounding_box_rect": "660.5,1946.5,117.046875,19", "class": "artist--Q4Rf9", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1322',
#    'rank': 30,
#    'score': 0.01912710629403591,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "1012", "bounding_box_rect": "660.5,1226.5,117.046875,19", "class": "artist--Q4Rf9", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1012',
#    'rank': 31,
#    'score': 0.01903369091451168,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "1042", "bounding_box_rect": "660.5,1298.5,117.046875,19", "class": "artist--Q4Rf9", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1042',
#    'rank': 32,
#    'score': 0.01834089867770672,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "1112", "bounding_box_rect": "660.5,1442.5,117.046875,19", "class": "artist--Q4Rf9", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1112',
#    'rank': 33,
#    'score': 0.017400292679667473,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "1287", "bounding_box_rect": "660.5,1874.5,117.046875,19", "class": "artist--Q4Rf9", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1287',
#    'rank': 34,
#    'score': 0.01638784445822239,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "1636", "bounding_box_rect": "532,2786.5625,216,22.390625", "class": "link--L6Xda", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1636',
#    'rank': 35,
#    'score': 0.015423399396240711,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "874", "bounding_box_rect": "356,843,223,67", "class": "rTitle--ZJtaB", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '874',
#    'rank': 36,
#    'score': 0.014878473244607449,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "908", "bounding_box_rect": "318,935.5,320,48", "class": "col--tazfa c1---FDvZ", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '908',
#    'rank': 37,
#    'score': 0.008638046681880951,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "194", "bounding_box_rect": "24,26,230,18", "class": "logo-container--sx6lA logo-container--mmgKq", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '194',
#    'rank': 38,
#    'score': 0.00712871877476573,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "890", "bounding_box_rect": "875,872,239,34", "class": "byted-input-inner__wrapper byted-input-inner__wrapper-border byted-input-inner__wrapper-size-md byted-input-inner__wrapper-add-suffix", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '890',
#    'rank': 39,
#    'score': 0.007119645830243826,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "839", "bounding_box_rect": "356,515,570,67", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '839',
#    'rank': 40,
#    'score': 0.006794496905058622,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "299", "bounding_box_rect": "842,25,84,20", "class": "navTitle--f6bh8", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '299',
#    'rank': 41,
#    'score': 0.0053549413569271564,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "242", "bounding_box_rect": "450,173,195,25", "class": "dropdownItem--VF-DB", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '242',
#    'rank': 42,
#    'score': 0.005092751234769821,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "303", "bounding_box_rect": "934,25,24,12", "class": "newLabel--MrU22", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '303',
#    'rank': 43,
#    'score': 0.004269091412425041,
#    'tag': 'span'},
#   {'attributes': '{"backend_node_id": "257", "bounding_box_rect": "450,308,195,25", "class": "dropdownItem--VF-DB", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '257',
#    'rank': 44,
#    'score': 0.004260167945176363,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "344", "bounding_box_rect": "62,455,200,46", "class": "byted-menu-line-title", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '344',
#    'rank': 45,
#    'score': 0.0037930267862975597,
#    'tag': 'span'},
#   {'attributes': '{"backend_node_id": "692", "bounding_box_rect": "62,2071,200,46", "class": "byted-menu-line-title", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '692',
#    'rank': 46,
#    'score': 0.0034393491223454475,
#    'tag': 'span'},
#   {'attributes': '{"backend_node_id": "809", "bounding_box_rect": "62,2634,70.1875,34", "class": "byted-radio byted-radio-size-md radio--tZPUV", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '809',
#    'rank': 47,
#    'score': 0.002971275243908167,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "881", "bounding_box_rect": "746,872,130,34", "class": "byted-input-inner__wrapper byted-input-inner__wrapper-border byted-input-inner__wrapper-size-md byted-input-inner__wrapper-add-suffix", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '881',
#    'rank': 48,
#    'score': 0.00291188876144588,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "292", "bounding_box_rect": "760,86.5,18,18", "alt": "navArrow", "title": "navArrow", "class": "rightIcon--6UFw8", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '292',
#    'rank': 49,
#    'score': 0.0028169318102300167,
#    'tag': 'img'},
#   {'attributes': '{"backend_node_id": "611", "bounding_box_rect": "62,1668,81,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '611',
#    'rank': 50,
#    'score': 0.002677032258361578,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "605", "bounding_box_rect": "62,1637,44,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '605',
#    'rank': 51,
#    'score': 0.002652354072779417,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "211", "bounding_box_rect": "323,173,194,25", "class": "dropdownItem--VF-DB", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '211',
#    'rank': 52,
#    'score': 0.002578875981271267,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "489", "bounding_box_rect": "62,1064,83,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '489',
#    'rank': 53,
#    'score': 0.0024186300579458475,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "111", "bounding_box_rect": "40,3245.6875,1200,154", "alt": "creativity", "title": "creativity", "class": "", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '111',
#    'rank': 54,
#    'score': 0.0023941167164593935,
#    'tag': 'img'},
#   {'attributes': '{"backend_node_id": "950", "bounding_box_rect": "662.515625,1082.5,116.609375,19", "class": "artist--Q4Rf9", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '950',
#    'rank': 55,
#    'score': 0.0022354586981236935,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "795", "bounding_box_rect": "62,2566,61.1875,34", "class": "byted-radio byted-radio-size-md radio--tZPUV", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '795',
#    'rank': 56,
#    'score': 0.0021304129622876644,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "802", "bounding_box_rect": "62,2600,69.1875,34", "class": "byted-radio byted-radio-size-md radio--tZPUV", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '802',
#    'rank': 57,
#    'score': 0.002014703582972288,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "1213", "bounding_box_rect": "385.65625,1646.5,251.84375,20", "class": "title--Dx5N-", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1213',
#    'rank': 58,
#    'score': 0.002012636512517929,
#    'tag': 'span'},
#   {'attributes': '{"backend_node_id": "763", "bounding_box_rect": "62,2427,58,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '763',
#    'rank': 59,
#    'score': 0.0018806307343766093,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "563", "bounding_box_rect": "62,1420,51,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '563',
#    'rank': 60,
#    'score': 0.0017855868209153414,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "1164", "bounding_box_rect": "1130.703125,1507.5,74,26", "class": "byted-tag byted-tag-size-md byted-tag-default-light commonTag--zIh8J", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1164',
#    'rank': 61,
#    'score': 0.0017000545049086213,
#    'tag': 'span'},
#   {'attributes': '{"backend_node_id": "331", "bounding_box_rect": "678.5,327.5,52,28", "class": "navItem--d5sIk grayWord--Gb6Hd", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '331',
#    'rank': 62,
#    'score': 0.0014647131320089102,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "241", "bounding_box_rect": "511,131.5,18,18", "alt": "navArrow", "title": "navArrow", "class": "rightIcon--6UFw8", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '241',
#    'rank': 63,
#    'score': 0.0014437565114349127,
#    'tag': 'img'},
#   {'attributes': '{"backend_node_id": "653", "bounding_box_rect": "62,1885,111,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '653',
#    'rank': 64,
#    'score': 0.0014389866264536977,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "1490", "bounding_box_rect": "385.65625,2320.5,251.84375,17", "class": "tool--2gk6l", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1490',
#    'rank': 65,
#    'score': 0.001358522567898035,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "276", "bounding_box_rect": "663,131.5,18,18", "alt": "navArrow", "title": "navArrow", "class": "rightIcon--6UFw8", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '276',
#    'rank': 66,
#    'score': 0.0013231647899374366,
#    'tag': 'img'},
#   {'attributes': '{"backend_node_id": "293", "bounding_box_rect": "700,128,91,25", "class": "dropdownItem--VF-DB", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '293',
#    'rank': 67,
#    'score': 0.00131609954405576,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "1285", "bounding_box_rect": "385.65625,1888.5,251.84375,17", "class": "tool--2gk6l", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1285',
#    'rank': 68,
#    'score': 0.0012873668456450105,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "261", "bounding_box_rect": "567,311.5,18,18", "alt": "navArrow", "title": "navArrow", "class": "rightIcon--6UFw8", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '261',
#    'rank': 69,
#    'score': 0.0012601189082488418,
#    'tag': 'img'},
#   {'attributes': '{"backend_node_id": "110", "bounding_box_rect": "356,461,320,34", "class": "byted-input-inner__wrapper byted-input-inner__wrapper-border byted-input-inner__wrapper-size-md byted-input-inner__wrapper-add-suffix", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '110',
#    'is_original_target': True,
#    'is_top_level_target': True,
#    'rank': 70,
#    'score': 0.0012499975273385644,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "593", "bounding_box_rect": "62,1575,107,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '593',
#    'rank': 71,
#    'score': 0.0012266425183042884,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "1609", "bounding_box_rect": "286,2725.78125,216,22.390625", "class": "link--L6Xda", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1609',
#    'rank': 72,
#    'score': 0.0012069811346009374,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "948", "bounding_box_rect": "385.515625,1096.5,254,17", "class": "tool--2gk6l", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '948',
#    'rank': 73,
#    'score': 0.0012064604088664055,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "507", "bounding_box_rect": "62,1157,74,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '507',
#    'rank': 74,
#    'score': 0.0011598881101235747,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "977", "bounding_box_rect": "660.5,1154.5,117.046875,19", "class": "artist--Q4Rf9", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '977',
#    'rank': 75,
#    'score': 0.0011445720447227359,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "1182", "bounding_box_rect": "660.5,1586.5,117.046875,19", "class": "artist--Q4Rf9", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1182',
#    'rank': 76,
#    'score': 0.0011445720447227359,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "447", "bounding_box_rect": "62,847,103,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '447',
#    'rank': 77,
#    'score': 0.001135218539275229,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "1383", "bounding_box_rect": "385.65625,2078.5,251.84375,20", "class": "title--Dx5N-", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1383',
#    'rank': 78,
#    'score': 0.0011340928031131625,
#    'tag': 'span'},
#   {'attributes': '{"backend_node_id": "415", "bounding_box_rect": "62,708,159,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '415',
#    'rank': 79,
#    'score': 0.0011158679844811559,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "1527", "bounding_box_rect": "660.5,2378,117.046875,19", "class": "artist--Q4Rf9", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1527',
#    'rank': 80,
#    'score': 0.001104777562431991,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "860", "bounding_box_rect": "781.3125,612,210,197", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '860',
#    'rank': 81,
#    'score': 0.0011032373877242208,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "1422", "bounding_box_rect": "662.515625,2162.5,116.609375,19", "class": "artist--Q4Rf9", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1422',
#    'rank': 82,
#    'score': 0.0011030114255845547,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "1420", "bounding_box_rect": "385.515625,2176.5,254,17", "class": "tool--2gk6l", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1420',
#    'rank': 83,
#    'score': 0.0010976613266393542,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "1638", "bounding_box_rect": "532,2816.953125,216,22.390625", "class": "link--L6Xda", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1638',
#    'rank': 84,
#    'score': 0.001069909310899675,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "216", "bounding_box_rect": "477,176.5,18,18", "alt": "navArrow", "title": "navArrow", "class": "rightIcon--6UFw8", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '216',
#    'rank': 85,
#    'score': 0.0010549819562584162,
#    'tag': 'img'},
#   {'attributes': '{"backend_node_id": "1525", "bounding_box_rect": "385.65625,2392,251.84375,17", "class": "tool--2gk6l", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1525',
#    'rank': 86,
#    'score': 0.0010466495295986533,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "1643", "bounding_box_rect": "778,2695.390625,216,22.390625", "class": "link--L6Xda", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1643',
#    'rank': 87,
#    'score': 0.0010362847242504358,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "1357", "bounding_box_rect": "662.515625,2018.5,116.609375,19", "class": "artist--Q4Rf9", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1357',
#    'rank': 88,
#    'score': 0.0010320122819393873,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "1075", "bounding_box_rect": "385.65625,1384.5,251.84375,17", "class": "tool--2gk6l", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1075',
#    'rank': 89,
#    'score': 0.0009845532476902008,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "975", "bounding_box_rect": "385.65625,1168.5,251.84375,17", "class": "tool--2gk6l", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '975',
#    'rank': 90,
#    'score': 0.0009783030254766345,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "355", "bounding_box_rect": "62,501,168,34", "class": "byted-radio byted-radio-size-md byted-radio-checked radio--tZPUV", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '355',
#    'rank': 91,
#    'score': 0.0009697034256532788,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "297", "bounding_box_rect": "773,131.5,18,18", "alt": "navArrow", "title": "navArrow", "class": "rightIcon--6UFw8", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '297',
#    'rank': 92,
#    'score': 0.000969504879321903,
#    'tag': 'img'},
#   {'attributes': '{"backend_node_id": "1492", "bounding_box_rect": "660.5,2306.5,117.046875,19", "class": "artist--Q4Rf9", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1492',
#    'rank': 93,
#    'score': 0.0009650872088968754,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "727", "bounding_box_rect": "62,2241,67,31", "class": "byted-checkbox byted-check-group-checkbox", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '727',
#    'rank': 94,
#    'score': 0.000951779424212873,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "1010", "bounding_box_rect": "385.65625,1240.5,251.84375,17", "class": "tool--2gk6l", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1010',
#    'rank': 95,
#    'score': 0.0009477947023697197,
#    'tag': 'a'},
#   {'attributes': '{"backend_node_id": "1161", "bounding_box_rect": "1043.703125,1507.5,198.296875,33", "class": "tags--LC91v", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '1161',
#    'rank': 96,
#    'score': 0.0008899345993995667,
#    'tag': 'div'},
#   {'attributes': '{"backend_node_id": "816", "bounding_box_rect": "62,2668,82,34", "class": "byted-radio byted-radio-size-md radio--tZPUV", "is_clickable": "true", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '816',
#    'rank': 97,
#    'score': 0.000870579679030925,
#    'tag': 'label'},
#   {'attributes': '{"backend_node_id": "246", "bounding_box_rect": "537,176.5,18,18", "alt": "navArrow", "title": "navArrow", "class": "rightIcon--6UFw8", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '246',
#    'rank': 98,
#    'score': 0.0008668036316521466,
#    'tag': 'img'},
#   {'attributes': '{"backend_node_id": "271", "bounding_box_rect": "687,86.5,18,18", "alt": "navArrow", "title": "navArrow", "class": "rightIcon--6UFw8", "data_pw_testid_buckeye_candidate": "1"}',
#    'backend_node_id': '271',
#    'rank': 99,
#    'score': 0.0008587090997025371,
#    'tag': 'img'}],
#  'actions_so_far': [],
#  'task': 'What are the romantic reggae musics from BCD Studio that can be used in tik tok series in andorra',
#  'screenshot': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x3464>,
#  'operation': '{"original_op": "CLICK", "value": "", "op": "CLICK"}'}
